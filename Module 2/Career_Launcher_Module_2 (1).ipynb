# %%
# Imporing necessary Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
 #Importing Data_set_from previous module
df = pd.read_csv('./stock_data/RBLBANK1.csv')
df.head()
# Out:
#          Date   Symbol Series      Date.1  Prev Close  Open Price  High Price  \
# 0  2017-05-15  RBLBANK     EQ  2017-05-15      556.55      557.50       564.9
# 1  2017-05-16  RBLBANK     EQ  2017-05-16      563.90      564.80       567.7
# 2  2017-05-17  RBLBANK     EQ  2017-05-17      562.60      563.00       569.9
# 3  2017-05-18  RBLBANK     EQ  2017-05-18      564.25      559.80       563.0
# 4  2017-05-19  RBLBANK     EQ  2017-05-19      552.15      560.95       567.0
#
#    Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0      551.1      564.25       563.90  ...                 888219
# 1      559.0      561.60       562.60  ...                 495571
# 2      558.0      564.70       564.25  ...                 831318
# 3      551.0      553.50       552.15  ...                1050920
# 4      551.4      553.80       555.45  ...                1292735
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
# Checking if the data contains null values
df.isnull().sum()
# Out:
# Date                      0
# Symbol                    0
# Series                    0
# Date.1                    0
# Prev Close                0
# Open Price                0
# High Price                0
# Low Price                 0
# Last Price                0
# Close Price               0
# Average Price             0
# Total Traded Quantity     0
# Turnover                  0
# No. of Trades             0
# Deliverable Qty           0
# % Dly Qt to Traded Qty    0
# Month                     0
# Year                      0
# VWAP                      0
# Day_Perc_Change           0
# Trend                     0
# dtype: int64

# %%
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'].head()
# Out:
# 0   2017-05-15
# 1   2017-05-16
# 2   2017-05-17
# 3   2017-05-18
# 4   2017-05-19
# Name: Date, dtype: datetime64[ns]

# %%
# changing index to date
df.index = df['Date']
df.head()
# Out:
#                  Date   Symbol Series      Date.1  Prev Close  Open Price  \
# Date
# 2017-05-15 2017-05-15  RBLBANK     EQ  2017-05-15      556.55      557.50
# 2017-05-16 2017-05-16  RBLBANK     EQ  2017-05-16      563.90      564.80
# 2017-05-17 2017-05-17  RBLBANK     EQ  2017-05-17      562.60      563.00
# 2017-05-18 2017-05-18  RBLBANK     EQ  2017-05-18      564.25      559.80
# 2017-05-19 2017-05-19  RBLBANK     EQ  2017-05-19      552.15      560.95
#
#             High Price  Low Price  Last Price  Close Price  ...  \
# Date                                                        ...
# 2017-05-15       564.9      551.1      564.25       563.90  ...
# 2017-05-16       567.7      559.0      561.60       562.60  ...
# 2017-05-17       569.9      558.0      564.70       564.25  ...
# 2017-05-18       563.0      551.0      553.50       552.15  ...
# 2017-05-19       567.0      551.4      553.80       555.45  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Date.1', 'Prev Close', 'Open Price',
#        'High Price', 'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty', 'Month', 'Year', 'VWAP', 'Day_Perc_Change',
#        'Trend'],
#       dtype='object')

# %%
df.drop(labels=['Date.1','Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  RBLBANK     EQ      556.55      557.50       564.9      551.1
# 2017-05-16  RBLBANK     EQ      563.90      564.80       567.7      559.0
# 2017-05-17  RBLBANK     EQ      562.60      563.00       569.9      558.0
# 2017-05-18  RBLBANK     EQ      564.25      559.80       563.0      551.0
# 2017-05-19  RBLBANK     EQ      552.15      560.95       567.0      551.4
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15      564.25       563.90         560.31                 888219
# 2017-05-16      561.60       562.60         562.26                 495571
# 2017-05-17      564.70       564.25         563.94                 831318
# 2017-05-18      553.50       552.15         555.33                1050920
# 2017-05-19      553.80       555.45         558.44                1292735
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# ...

# %%
# Ploting close price of the stock
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(16,7))
plt.plot(df['Close Price'],label='RBLBANK')
plt.ylabel('price in rupees')
plt.legend(loc='best')

# %% [markdown]
# As seen from above graph we could see from the beginning there was a strong support at 510 and the price was in a range bound with a strong resistance near the 540 ish region and after 2018-01 there was a big bear drop following an uptrend to 640 and there was a correction at first 640 and the price declined to sub 460s a 20% percent drop in less than a month

# %%
# ploting stem() for percentage change 
plt.figure(figsize=(16,9))
plt.stem(df['Day_Perc_Change'],label = ('stem() plot') )
# Out:
# <StemContainer object of 3 artists>

# %%
#plotting both total_traded_quantity and stem() plot
plt.figure(figsize=(16,9))
plt.title('Total Traded Quantity')
plt.xlabel('Dates')
plt.ylabel('Values')
plt.plot(df['Total Traded Quantity'])
plt.figure(figsize=(16,9))
plt.xlabel('Dates')
plt.ylabel('Values')
plt.stem(df['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %%
#ploting pie chart
plt.figure(figsize=(7,7))
plt.pie(x=df['Trend'].value_counts(),labels=df['Trend'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x166c9cd4dc8>,
# ...
#  [Text(0.5898819425819978, 0.9284607120474667, 'Slight or no change'),
#   Text(-0.9358880966692229, 0.5780254929610454, 'Negative'),
#   Text(-0.9131566066691434, -0.6133066212723415, 'Positive'),
#   Text(-0.027978902177886265, -1.0996441156269243, 'Slight negative'),
#   Text(0.7450096290885878, -0.8092963935204981, 'Slight positive'),
#   Text(1.0448574816149645, -0.3439081899478903, 'Among top gainers'),
#   Text(1.0943104890806359, -0.111734298619984, 'Among top losers'),
#   Text(1.0999777553346386, -0.0069955535142138935, 'Bear drop')])

# %%
#grouping by trend
by_Trend = df.groupby(df['Trend'])

# %%
# groupby mean for barplot
mean_bar = by_Trend['Total Traded Quantity'].mean()

# %%
# groupby median for barplot
median_bar = by_Trend['Total Traded Quantity'].median()

# %%
#importing seaborn and ploting barplots 
import seaborn as sns
plt.figure(figsize=(14,5))
plt.title('Bar plot of Trends')
sns.countplot(data=df,x=df['Trend'])

# %%
# Ploting mean and median barpolots 
plt.figure(figsize=(15,5))
plt.xlabel('Trend')
plt.ylabel('values')
plt.title('mean')
plt.bar(df['Trend'].value_counts().index,mean_bar)
plt.figure(figsize=(15,5))
plt.xlabel('Trend')
plt.ylabel('values')
plt.title('median')
plt.bar(df['Trend'].value_counts().index,median_bar,color = 'Red')
# Out:
# <BarContainer object of 8 artists>

# %%
# Ploting histogram plot for Day_Perc_Change
plt.figure(figsize=(10,6))
plt.hist(x=df['Day_Perc_Change'],bins=50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  2.,  0.,  2.,  0.,  0.,  0.,  3.,  1.,  3.,
#          2.,  1.,  3.,  3., 13.,  9., 16., 21., 26., 27., 42., 43., 55.,
#         42., 38., 32., 22., 20., 14., 11.,  9.,  6.,  6.,  6.,  2.,  3.,
#          4.,  2.,  1.,  0.,  1.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([-7.28116973, -6.9956764 , -6.71018307, -6.42468974, -6.13919641,
#         -5.85370308, -5.56820975, -5.28271642, -4.99722309, -4.71172976,
#         -4.42623643, -4.1407431 , -3.85524977, -3.56975645, -3.28426312,
#         -2.99876979, -2.71327646, -2.42778313, -2.1422898 , -1.85679647,
#         -1.57130314, -1.28580981, -1.00031648, -0.71482315, -0.42932982,
#         -0.14383649,  0.14165684,  0.42715017,  0.7126435 ,  0.99813683,
#          1.28363016,  1.56912349,  1.85461682,  2.14011015,  2.42560348,
#          2.71109681,  2.99659013,  3.28208346,  3.56757679,  3.85307012,
#          4.13856345,  4.42405678,  4.70955011,  4.99504344,  5.28053677,
# ...

# %%
#reading titan dataset
df1 = pd.read_csv('./stock_data/TITAN.csv')
df1.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0  TITAN     EQ  15-May-2017      495.00      489.65       490.0     472.40
# 1  TITAN     EQ  16-May-2017      483.65      486.00       491.0     480.80
# 2  TITAN     EQ  17-May-2017      488.30      490.00       490.1     477.30
# 3  TITAN     EQ  18-May-2017      481.75      479.00       482.6     470.05
# 4  TITAN     EQ  19-May-2017      471.65      475.00       479.5     460.35
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      486.00       483.65         479.93                3897357
# 1      490.00       488.30         487.32                1308863
# 2      481.00       481.75         482.25                 859054
# 3      470.85       471.65         474.78                 811219
# 4      469.65       471.15         469.05                1022479
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
#reading reliance dataset
df2 = pd.read_csv('./stock_data/RELIANCE.csv')
df2.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  RELIANCE     EQ  15-May-2017     1350.45     1356.40     1356.40
# 1  RELIANCE     EQ  16-May-2017     1344.10     1346.05     1376.90
# 2  RELIANCE     EQ  17-May-2017     1356.30     1353.00     1365.95
# 3  RELIANCE     EQ  18-May-2017     1353.10     1340.25     1350.00
# 4  RELIANCE     EQ  19-May-2017     1327.35     1333.00     1335.70
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1333.50     1343.60      1344.10        1344.22                1540213
# 1    1341.00     1356.20      1356.30        1360.59                2892947
# 2    1347.75     1350.00      1353.10        1354.16                2250304
# 3    1324.10     1327.45      1327.35        1336.14                2237916
# 4    1310.00     1318.20      1318.85        1321.99                2928883
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
#reading tcs dataset
df3 = pd.read_csv('./stock_data/TCS.csv')
df3.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TCS     EQ  15-May-2017     2360.65      2375.1     2377.95    2341.60
# 1    TCS     EQ  16-May-2017     2365.10      2380.0     2435.00    2373.45
# 2    TCS     EQ  17-May-2017     2429.15      2433.5     2460.75    2423.00
# 3    TCS     EQ  18-May-2017     2455.35      2450.0     2572.00    2442.25
# 4    TCS     EQ  19-May-2017     2536.20      2536.2     2540.55    2486.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     2368.00      2365.10        2352.60                 908802
# 1     2425.10      2429.15        2410.26                1800513
# 2     2450.00      2455.35        2443.31                1438099
# 3     2525.00      2536.20        2525.78                2569297
# 4     2503.85      2507.15        2506.58                 893022
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
#reading maruthi dataset
df4 = pd.read_csv('./stock_data/MARUTI.csv')
df4.head()
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MARUTI     EQ  15-May-2017     6730.20      6759.4     6839.10    6733.45
# 1  MARUTI     EQ  16-May-2017     6823.90      6850.0     6977.55    6830.00
# 2  MARUTI     EQ  17-May-2017     6953.95      6950.0     6979.00    6885.85
# 3  MARUTI     EQ  18-May-2017     6958.20      6918.3     6948.00    6814.45
# 4  MARUTI     EQ  19-May-2017     6831.05      6854.8     6893.90    6691.55
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      6824.0      6823.90        6796.84                 336356
# 1      6968.4      6953.95        6902.22                 707624
# 2      6945.0      6958.20        6931.60                 445461
# 3      6822.0      6831.05        6869.68                 406814
# 4      6756.3      6790.55        6791.60                 552223
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
#reading  infy dataset
df5 = pd.read_csv('./stock_data/INFY.csv')
df5.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
# only considerig close price from each dataset.
a = df1['Close Price']
b = df2['Close Price']
c = df3['Close Price']
d = df4['Close Price']
e = df5['Close Price']

# %%
# creating a new Dataset using concat()
da = pd.concat([a,b,c,d,e],axis=1)

# %%
da.head()
# Out:
#    Close Price  Close Price  Close Price  Close Price  Close Price
# 0       483.65      1344.10      2365.10      6823.90       951.55
# 1       488.30      1356.30      2429.15      6953.95       955.00
# 2       481.75      1353.10      2455.35      6958.20       952.80
# 3       471.65      1327.35      2536.20      6831.05       961.75
# 4       471.15      1318.85      2507.15      6790.55       957.95

# %%
# Renaming dataframe columns
da.columns = ['TITAN','RELIANCE','TCS','MARUTI','INFY']

# %%
da.head()
# Out:
#     TITAN  RELIANCE      TCS   MARUTI    INFY
# 0  483.65   1344.10  2365.10  6823.90  951.55
# 1  488.30   1356.30  2429.15  6953.95  955.00
# 2  481.75   1353.10  2455.35  6958.20  952.80
# 3  471.65   1327.35  2536.20  6831.05  961.75
# 4  471.15   1318.85  2507.15  6790.55  957.95

# %%
# Adding RBLBANK column
df6 = pd.read_csv('./stock_data/RBLBANK1.csv')
da['RBLBANK'] = df6['Close Price']

# %%
da.head()
# Out:
#     TITAN  RELIANCE      TCS   MARUTI    INFY  RBLBANK
# 0  483.65   1344.10  2365.10  6823.90  951.55   563.90
# 1  488.30   1356.30  2429.15  6953.95  955.00   562.60
# 2  481.75   1353.10  2455.35  6958.20  952.80   564.25
# 3  471.65   1327.35  2536.20  6831.05  961.75   552.15
# 4  471.15   1318.85  2507.15  6790.55  957.95   555.45

# %%
#Checking datacorrelation using heatmap
corr = da.corr()
plt.figure(figsize=(15,5))
sns.heatmap(corr,annot=True)

# %%
# Plotting pairplot to check data corelation
sns.pairplot(da,dropna=True)

# %%
# computing voltality for Day_Perc_Change 
rolling_std = df['Day_Perc_Change'].rolling(window=7).std()
rolling_std.isnull().sum()
rolling_std.dropna(inplace = True,axis=0)

# %%
#ploting voltality of RBLBANK
plt.figure(figsize=(16,8))
plt.title('voltality of RBLBANK')
plt.plot(rolling_std)

# %%
#Reading nifty50 index dataset
nifty = pd.read_csv("./stock_data/Nifty50.csv")
nifty.head()
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77

# %%
# computig per_change() for nifty50
nifpc = nifty['Close'].pct_change() * 100

# %%
df.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty', 'Month', 'Year', 'VWAP', 'Day_Perc_Change',
#        'Trend'],
#       dtype='object')

# %%
#Computing nifty50 voltality
nifty_voltality = nifpc.rolling(window=7).std()
nifty_voltality.index = df.index

# %%
#comparing voltality indexs of both RBLBANK and Nifty50
plt.figure(figsize=(16,8))
plt.plot(rolling_std)
plt.plot(nifty_voltality)
plt.legend(loc='best',labels=['RBLBANK','Nifty50'])
plt.title('Voltality comparision for RBLBANK and Nitfy 50')
# Out:
# Text(0.5, 1.0, 'Voltality comparision for RBLBANK and Nitfy 50')

# %%
price = df['Close Price']

# %%
#defining moving average for 21 days
ma_21 = price.rolling(window=21).mean()

# %%
#defining moving average for 34 days
ma_34 = price.rolling(window=34).mean()

# %%
#ploting simple moving avrages 
plt.figure(figsize=(16,8))
plt.plot(price, label='Price')
plt.plot(ma_21,label='sma_21days')
plt.plot(ma_34,label='sma_34days')
plt.legend(loc='best')
plt.ylabel('Price in $')
# Out:
# Text(0, 0.5, 'Price in $')

# %%
#computing bollinger bands 
df['30 Day STD'] = df['Close Price'].rolling(window=20).std()
df['Middle_band'] = df['Close Price'].rolling(window=20).mean()
df['Upper_band'] = df['Middle_band'] + (df['30 Day STD'] * 2)
df['Lower_band'] = df['Middle_band'] - (df['30 Day STD'] * 2)
#df['Middle_band'] = (df['Upper Band']+ df['Lower Band']) /2

# %%
#ploting bolinger bands for RBLBANK stockdata
plt.figure(figsize=(16,8))
plt.plot(df['Close Price'],label = 'Close price',linewidth = 2.5,)
plt.plot(df['Middle_band'],label = 'Middle_band', dashes = [2, 2, 5, 2])
plt.plot(df['Upper_band'],label = 'Upper_band',dashes = [6, 2])
plt.plot(df['Lower_band'],label = 'Lower_band', dashes = [6, 2])
plt.legend(loc='best')
plt.title('Bollinger bands for RBLBANK stock data')
# Out:
# Text(0.5, 1.0, 'Bollinger bands for RBLBANK stock data')

# %%
# exporting csv
export_csv = df.to_csv('./stock_data/RBLBANK2.csv')

# %%
df.head()

# %%
df['Upper Band']
